# %% [markdown]
# # 諸々をインポートする

# %%
from __future__ import print_function, division

# %matplotlib inline

import numpy as np

import nsfg
import first
import thinkstats2
import thinkplot

# %% [markdown]
# # NSFGからデータをロードする

# %%
live, firsts, others = first.MakeFrames()

# %% [markdown]
# # 課題とは関係ないけどPMFの方も一応見てみる
# dropnaというのは欠損値の削除をしているみたい(drop nan?)

# %%
first_wgt = firsts.totalwgt_lb 
first_wgt_dropna = first_wgt.dropna()
print('Firsts', len(first_wgt), len(first_wgt_dropna))
 
other_wgt = others.totalwgt_lb
other_wgt_dropna = other_wgt.dropna()
print('Others', len(other_wgt), len(other_wgt_dropna))

first_pmf = thinkstats2.Pmf(first_wgt_dropna, label='first')
other_pmf = thinkstats2.Pmf(other_wgt_dropna, label='other')

width = 0.4 / 16

# plot PMFs of birth weights for first babies and others
thinkplot.PrePlot(2)
thinkplot.Hist(first_pmf, align='right', width=width)
thinkplot.Hist(other_pmf, align='left', width=width)
thinkplot.Config(xlabel='Weight (pounds)', ylabel='PMF')
# Out:
# Firsts 4413 4363
# Others 4735 4675

# %% [markdown]
# # 肝心の課題4.1に入る
# - ロードしたデータに対してCdfクラスを用いて計算していく
# - ポンド表記の体重とかよくわからないので、解答に用いられてた8.5ポンドを使用
# - 第二子なので約82パーセンタイル

# %%
first_cdf = thinkstats2.Cdf(firsts.totalwgt_lb, label='first')
other_cdf = thinkstats2.Cdf(others.totalwgt_lb, label='other')

#first_cdf.PercentileRank(8.5)
other_cdf.PercentileRank(8.5)
# Out:
# 82.35294117647058

# %% [markdown]
# # 課題4.2に移る
# numpyのrandom.randomから1000個ランダムな数字を作る

# %%
t = np.random.random(1000)

# %% [markdown]
# 次にPMFを見てみる

# %%
pmf = thinkstats2.Pmf(t)
thinkplot.Pmf(pmf, linewidth=0.1)
thinkplot.Config(xlabel='Random variate', ylabel='PMF')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# 均等に1/1000の確率で揃ってるっぽい？

# %% [markdown]
# その次はCDFを見る

# %%
cdf = thinkstats2.Cdf(t)
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='Random variate', ylabel='CDF')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ちゃんと一直線を描いてるので一様分布っぽい
